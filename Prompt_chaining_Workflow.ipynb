# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict
from langchain_groq import ChatGroq
import os

# %%
### Create the Model:
model=ChatGroq(model="llama-3.1-8b-instant",
               api_key=os.getenv("API_KEY"))

# %%
### Defining state:
class prompt_chaining_State(TypedDict):
    topic:str
    outline:str
    blog_content:str

# %%
def detailed_outline(state:prompt_chaining_State) ->prompt_chaining_State:
    topic=state['topic']
    prompt=f"Create a detailed outline for a blog post about {topic}."
    outline=model.invoke(prompt).content
    state['outline']=outline
    return state

# %%
def blog_content_generator(state:prompt_chaining_State) ->prompt_chaining_State:
    outline=state['outline']
    topic=state['topic']
    prompt=f"Write a detailed blog post based on the following outline:{outline} and topic{topic}"
    blog_content=model.invoke(prompt).content
    state['blog_content']=blog_content
    return state

# %%
### Defining Graph, Nodes and Edges:
graph=StateGraph(state_schema=prompt_chaining_State)

### Adding Nodes:
graph.add_node(name="detailed_outline",node=detailed_outline)
graph.add_node(name="blog_content_generator",node=blog_content_generator)

### Adding Edges:
graph.add_edge(START,"detailed_outline")
graph.add_edge("detailed_outline","blog_content_generator")
graph.add_edge("blog_content_generator",END)

### compliling the Graph:
workflow=graph.compile()

# %%
initail_state=prompt_chaining_State(topic="The Future of AI",outline="",blog_content="")
final_state=workflow.invoke(initail_state)
print(final_state['blog_content'])
# Out:
# **The Future of AI: Emerging Trends, Challenges, and Opportunities**
#
# **Introduction**
#
# Artificial intelligence (AI) has been a rapidly evolving field over the past few decades, transforming various industries and aspects of life. Today, AI is no longer a distant concept, but a tangible reality that is changing the way we live, work, and interact with one another. As AI continues to advance, it is essential to understand the emerging trends, challenges, and opportunities that lie ahead. In this blog post, we will explore the future of AI, its potential to revolutionize various industries, and the importance of mitigating its challenges to ensure a responsible and beneficial development.
#
# **II. Emerging Trends in AI**
#
# The future of AI is marked by several emerging trends that promise to transform various industries and aspects of life. Some of the most significant trends include:
#
# ### **Explainable AI (XAI)**
#
# Explainable AI (XAI) refers to the development of AI systems that can provide transparent and interpretable explanations for their decisions and actions. XAI is essential in various industries, such as healthcare, finance, and education, where the need for accountability and trust in AI systems is critical. XAI techniques, such as feature importance and model interpretability, enable humans to understand how AI systems arrive at their conclusions, thereby improving trust and accountability.
#
# ### **Edge AI**
#
# Edge AI refers to the processing of AI models and data at the edge of the network, i.e., at the device or sensor level, rather than in the cloud. Edge AI offers several advantages, including real-time processing, reduced latency, and improved security. Applications of edge AI include smart home automation, automotive systems, and industrial control systems.
#
# ### **Quantum AI**
#
# Quantum AI is a new paradigm that combines quantum computing and AI to solve complex problems that are intractable using classical computing. Quantum AI has the potential to revolutionize various fields, including cryptography, optimization, and simulation. However, the development of practical quantum AI systems faces significant challenges, including the need for large-scale quantum computers and the complexity of quantum algorithms.
#
# ### **Synthetic Data**
#
# Synthetic data refers to artificially generated data that mimics real-world data. Synthetic data is essential in various applications, including data augmentation, data anonymization, and data sharing. Techniques for generating synthetic data include generative adversarial networks (GANs) and variational autoencoders (VAEs).
#
# ### **Human-AI Collaboration**
#
# Human-AI collaboration refers to the development of AI systems that can work alongside humans to enhance productivity, creativity, and decision-making. Human-AI collaboration has the potential to transform various industries, including healthcare, finance, and education. Techniques for human-AI collaboration include transfer learning, multi-agent systems, and human-in-the-loop (HITL) approaches.
#
# **III. AI in Various Industries**
#
# AI is poised to transform various industries, including healthcare, finance, education, transportation, and manufacturing. Some of the key applications and benefits of AI in these industries include:
#
# ### **Healthcare**
#
# AI-assisted diagnosis, personalized medicine, and precision healthcare are some of the key applications of AI in healthcare. AI can help doctors diagnose diseases more accurately and efficiently, develop targeted treatments, and optimize patient care.
#
# ### **Finance**
#
# AI-driven decision-making, risk management, and automated trading are some of the key applications of AI in finance. AI can help financial institutions make more informed decisions, manage risk more effectively, and automate trading processes.
#
# ### **Education**
#
# AI-powered adaptive learning, intelligent tutoring systems, and assessment tools are some of the key applications of AI in education. AI can help teachers personalize learning, improve student outcomes, and optimize educational resources.
#
# ### **Transportation**
#
# AI-enhanced autonomous vehicles, smart traffic management, and logistics optimization are some of the key applications of AI in transportation. AI can help improve road safety, reduce traffic congestion, and optimize logistics operations.
#
# ### **Manufacturing**
#
# AI-driven predictive maintenance, quality control, and supply chain optimization are some of the key applications of AI in manufacturing. AI can help manufacturers predict equipment failures, improve product quality, and optimize supply chain operations.
#
# **IV. Challenges and Concerns**
#
# While AI offers numerous benefits and opportunities, it also poses several challenges and concerns, including:
#
# ### **Job Displacement**
#
# AI has the potential to displace certain jobs, particularly those that involve repetitive or routine tasks. However, AI also creates new job opportunities, particularly in fields such as AI development, deployment, and maintenance.
#
# ### **Bias and Fairness**
#
# AI systems can perpetuate biases and unfairness if they are trained on biased data or designed with a particular worldview. Ensuring AI systems are unbiased and fair is essential to prevent adverse outcomes.
#
# ### **Security and Safety**
#
# AI systems can pose security and safety risks if they are not designed or deployed properly. Ensuring AI systems are secure and safe is critical to prevent malicious attacks and ensure public trust.
#
# ### **Regulation and Governance**
#
# Establishing guidelines and frameworks for AI development and deployment is essential to ensure accountability, transparency, and value alignment. Governments, industry leaders, and civil society organizations must work together to establish effective regulations and governance structures.
#
# ### **Ethics and Responsibility**
#
# Addressing accountability, transparency, and value alignment in AI development is essential to ensure AI systems are designed and deployed responsibly. Encouraging a culture of ethics and responsibility in AI development is critical to prevent adverse outcomes.
#
# **V. Opportunities and Benefits**
#
# Despite the challenges and concerns, AI offers numerous opportunities and benefits, including:
#
# ### **Improved Efficiency and Productivity**
#
# AI-driven automation and optimization can improve efficiency and productivity in various industries, including manufacturing, logistics, and finance.
#
# ### **Enhanced Decision-Making**
#
# AI-assisted insights and predictions can enhance decision-making in various fields, including healthcare, finance, and education.
#
# ### **New Business Models**
#
# AI-driven innovation and entrepreneurship can create new business models and opportunities, particularly in fields such as AI development, deployment, and maintenance.
#
# ### **Improved Quality of Life**
#
# AI-assisted healthcare, education, and transportation can improve quality of life for individuals and communities, particularly in areas such as healthcare, education, and transportation.
#
# ### **Environmental Sustainability**
#
# AI-driven energy efficiency and resource optimization can contribute to environmental sustainability, particularly in areas such as energy management, resource allocation, and waste reduction.
#
# **VI. Conclusion**
#
# The future of AI is marked by both exciting opportunities and daunting challenges. As AI continues to transform various industries and aspects of life, it is essential to understand the emerging trends, challenges, and opportunities that lie ahead. By embracing AI and mitigating its challenges, we can unlock its full potential and create a better future for all.
#
# **VII. Additional Resources**
#
# For those interested in learning more about AI and its future, we recommend the following resources:
#
# * **Books:**
# 	+ "Life 3.0: Being Human in the Age of Artificial Intelligence" by Max Tegmark
# 	+ "Deep Learning" by Ian Goodfellow, Yoshua Bengio, and Aaron Courville
# * **Articles:**
# 	+ "The Future of Artificial Intelligence" by Nick Bostrom
# 	+ "The Ethics of Artificial Intelligence" by Timnit Gebru
# * **Online Courses:**
# 	+ "Introduction to Artificial Intelligence" by Andrew Ng on Coursera
# 	+ "Deep Learning" by DeepLearning.ai on Coursera
# * **Organizations:**
# 	+ International Joint Conference on Artificial Intelligence (IJCAI)
# 	+ Association for the Advancement of Artificial Intelligence (AAAI)
# * **Research Initiatives:**
# 	+ Future of Life Institute (FLI)
# 	+ Machine Intelligence Research Institute (MIRI)
#
# Stay informed, engage with AI, and contribute to its responsible development. Follow this blog for future updates on AI and related topics.
